# %% [markdown]
# # INTRODUCTION
#
# From the `experiment.ipynb` file, we identified concepts such as **relative probability** based on the observations made during the experiment. There was also the concept of **statefulness**, which implied that information was being used to produce a response, leading to the development of the computational terminology associated with relativity. The interaction between the formula
#
# $$
# p_{\mathrm{obs}}=\gamma p_{\mathrm{exp}}
# $$
#
# and the Boltzmann distribution provided a good estimate of what the time-dilation or temperature-dilation term would be in the thermodynamic analogue, which subsequently gave rise to an energy-based system for describing the dilation terms.  We also identified issues with the original Lorentz transformations, where Galilean relativity would have resulted in incomplete terms. Computational relativity addressed this by specifying the presence of an energy cap, which subsequently provided the basis for the bridge between relativity and thermodynamics.
#
#
# Below, we identified two inferences. The first is that the term $\frac{v^2}{c^2}$ is potentially misrepresented due to an incompleteness in the Lorentz transformations, which rely heavily on Galilean relativity and therefore do not explicitly account for the causes of motion. The second is that the dilation term also contains descriptions of computational systems that can produce the effects associated with entropy and biological systems arising from random conditions.
#
# The first implication, the term is energy based:
#
# $\frac{k_B T}{k_e\gamma} \rightarrow \frac{\frac{1}{2}mv^2}{\frac{1}{2}mc^2}$
#
# And the second implication, of a multiple particle system:
#
# $\frac{k_B T}{k_e\gamma} \rightarrow$ (MULTIPLE PARTICLE SYSTEM)
#
# This also paved the way for the idea that time dilation could be produced because a process was taking too long to complete. The incorporation of computational terminology into relativity subsequently produced the intuition-driven \(K-e\) term, which became the skeleton of computational relativity and confirmed multiple formulas that had been derived prior to its creation.
#
# The following formula included the description of an energy cap $\frac{\frac{1}{2}mv^2}{\frac{1}{2}mc^2}$:
#
# $$
# \frac{1}{2}mv^2
# =
# \frac{1}{2}mv'^2
# -
# \frac{1}{2}\left(\frac{\frac{1}{2}mv^2}{\frac{1}{2}mc^2}\right)mv'^2
# $$
#
#
# Specifically, this included the confirmation that the derivative of the term derived from the \(\gamma p\) formulation provided an accurate estimate based on the preceding theoretical development, as well as the interpretation that the term itself indicated that entropy could arise as a consequence of a computational field concerned with the enumeration of particles.
#
# The \(K-e\) terminology was later confirmed through the Lorentz transformation and a corresponding thought experiment, both of which produced the same formula.
#
#
# $$v'=\frac{v}{\sqrt{1-\frac{v^2}{c^2}}}$$
#
# The incorporation of computational terminology into relativity provided a clearer framework for formulating and evaluating candidate equations, suggesting that the philosophy underlying computational relativity offers a more precise interpretation than previous formulations. In particular, the limitations of earlier approaches arose from treating the constancy of the speed of light as a foundational principle without providing a sufficiently explicit framework for describing the underlying mechanism. Without clearer definitions, such as those introduced through computational relativity, these conceptual limitations within the relativistic framework would have been difficult to identify and address.
#
# With the corrected interpretation of the Boltzmann distribution, we identified that the dilation associated with the enumeration of particles could be reformulated through the correspondence
#
# $$
# \frac{k_B T}{k_e\gamma}
# \;\rightarrow\;
# \frac{mv^2}{2k_e}.
# $$
#
# Under this interpretation, the \(k_e\) term incorporates the contribution associated with the multiplicity of particles, with the precise definition of this constant requiring a subsequent derivation. This became significant because \(k_e\) was later found to be connected to the structure of the Taylor series.
#
# Importantly, this connection was not established at the outset. Before the individual terms of the Taylor series had been formally interpreted, the Taylor expansion itself had already been nearly recovered from the original formulation. Thus, the mathematical structure of the Taylor series emerged during the attempt to reformulate the relativistic expression, while the physical interpretation of its individual terms—and their relationship to particle multiplicity through \(k_e\)—was identified only later.
#
#
# Before the interpretation of the individual terms in the Taylor series was recognized, the series itself had already been nearly reconstructed through the attempt to resolve inconsistencies in the original formulation. In particular, when the speed of light could no longer be treated as the limiting term in the formulation, a new representation of the terms was required. In attempting to rectify the original expression, the resulting formulation began to reproduce the mathematical structure of the Taylor series, including the operation of squaring the dilation term, which reduces to \(1-v^2/c^2\).
#
# The original expression was (which broke the rule that the speed of light was constant and needed rectification)
#
# $$
# \gamma
# =
# \frac{1}{\sqrt{1-\frac{mv^4}{2k_e c^2}}}.
# $$
#
# The original expression required rectification, and the resulting interpretation suggested that the dilation could be understood as being composed of successive contributions associated with different components of the system, represented schematically by
#
# $$
# 1
# -\frac{v_1^2}{c^2}
# -\frac{v_2^2}{c^2}
# -\frac{v_3^2}{c^2}
# -\frac{v_4^2}{c^2}
# -\frac{v_5^2}{c^2}.
# $$
#
# This interpretation provided the basis for identifying the additional terms within the total relativistic quantity. Rather than representing independent contributions added to the system, the terms can be understood as different portions of the same total computational quantity. In particular, the term
#
# $$
# \frac{mv^2}{2k_e}
# $$
#
# can be identified with the field of multiplicity (an enumeration of particles), while the remaining portion represents the contribution of motion. Thus, the total quantity
#
# $$
# \frac{mv_t^2}{mc^2}
# $$
#
# can be partitioned into field and non-field contributions:
#
# $$
# D_{\mathrm{field}}
# =
# \frac{mv_t^2}{mc^2}
# \times
# \frac{mv^2}{2k_e},
# $$
#
# and
#
# $$
# D_{\mathrm{motion}}
# =
# \frac{mv_t^2}{mc^2}
# \left(
# 1-\frac{mv^2}{2k_e}
# \right).
# $$
#
# The two terms therefore do not introduce an additional quantity beyond the original total. Instead, they describe how the original quantity can be partitioned into its motion and field components. Their recombination restores the complete original expression:
#
# $$
# D_{\mathrm{total}}
# =
# D_{\mathrm{motion}}
# +
# D_{\mathrm{field}}
# =
# \frac{mv_t^2}{mc^2}
# \left[
# 1-\frac{mv^2}{2k_e}
# +
# \frac{mv^2}{2k_e}
# \right]
# =
# \frac{mv_t^2}{mc^2}.
# $$
#
# In this way, the attempt to correct the original formulation led to the identification of the same mathematical structure that later appeared in the interpretation of the Taylor-series terms, with the individual terms providing a decomposition of the total relativistic quantity into distinct computational contributions.
#
#
# As the theory developed, the terminology introduced by computational relativity also provided clearer interpretations of the terms appearing in the Taylor series. These terms were subsequently related to the multiplicity associated with the dilation factor in the Boltzmann distribution.
#
# $$
# \boxed{
# \gamma
# =
# 1
# +\frac12\frac{mv^2}{mc^2}
# +\frac38\left(\frac{mv^2}{mc^2}\right)^2
# +\frac5{16}\left(\frac{mv^2}{mc^2}\right)^3
# +\frac{35}{128}\left(\frac{mv^2}{mc^2}\right)^4
# +\frac{63}{256}\left(\frac{mv^2}{mc^2}\right)^5
# +\cdots
# }
# $$
#
# In this interpretation, the index \(N\) in the Taylor expansion can be understood as specifying a system containing a multiplicity of particle states, rather than merely representing a mathematical order in an expansion. Classical interpretations do not provide an equally direct physical interpretation of these terms (in the taylor series), without introducing the additional conceptual framework supplied by computational relativity. That is computational relativity, and it's philosophy provided better description of these terms.
#
# Furthermore, the same terminology suggests that the expansion terms may serve as an alternative description of structures traditionally expressed through statistical mechanics. In this sense, computational relativity establishes a conceptual bridge between thermodynamics and relativity while providing an alternative framework for describing the partitioning and distribution of energy within a physical system. In this sense, statistical mechanics and thermodynamics can be reformulated within the framework of computational relativity. As demonstrated, conventional thermodynamic terminology, such as multiplicity, does not by itself provide a sufficiently complete description of the underlying system. Computational relativity therefore provides an additional framework in which these concepts can be expressed more precisely and their relationship to relativistic processes can be made explicit. For example, computational relativity provides a framework in which probability can be related directly to dilation and, consequently, to energy. In this way, it describes the same underlying statistical system represented by the Boltzmann distribution, but expresses it using terminology that provides a more direct and physically meaningful interpretation of the relationships between probability, dilation, and energy.
#
#
# ---
#
# ## Proposition 1: Absolute Reference Frame and Computational Relativity
#
# We reinterpret Lorentz’s results using a computational-field view in which only an absolute reference frame is truly inertial. Within this framework, the absolute reference frame is defined by the following premises:
#
# 1. the absolute reference frame is one which is non-moving, or infinitely far away from a gravitational field
# 2. everyone agrees on the same amount of time that elapsed relative to the absolute reference frame
# 3. the greatest amount of time elapses in the absolute reference frame
#
# Let $k_B=\frac{B}{S}$ be the bibs-rate constant (units: bibs/s), representing a system-specific computational overhead that scales how proper time is counted in bibs. The bibs elapsed over a proper-time interval $\Delta\tau$ is
#
# $$
# \boxed{\Delta b=\frac{k_B}{\rho}\,\Delta\tau}
# $$
#
# Where
#
# $$ \rho = \sqrt{1 - p} = \sqrt{1 - \frac{v^2}{u^2}} $$
#
# ### Corollary 1: Interpreting Process Requirements
#
#
# Within Computational Relativity, dilation occurs because a process is taking too long to complete, the term
#
# $$
# 1-\frac{v^2}{c^2}
# =
# \frac{c^2}{c^2}-\frac{v^2}{c^2}
# $$
#
# represents the proportion of computational capacity remaining available to the system as its velocity increases. The term may also be interpreted as a measure of computational complexity, representing the amount of physical change that can be produced through space and time for a given amount of energy. As this capacity decreases, more energy is required to produce or maintain the same degree of motion or change.
#
# For example, the increased energy required to maintain the same velocity can be seen in the following comparison:
#
# $$
# 0.9c \text{ without dilation}
# \longrightarrow
# 3.64\times10^{16}\mathrm{J}
# $$
#
# $$
# 0.9c \text{ with dilation}
# \longrightarrow
# 1.16\times10^{17}\mathrm{J}
# $$
#
# Therefore, additional energy is required to compensate for this reduction and preserve the same level of complexity in terms of motion. Furthermore, when the available energy is partitioned, the amount of physical change that can be produced through space and time is correspondingly reduced.

# %% [markdown]
# ---
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
#
# ## Proposition 2: Energy can be partitioned
#
# The kinetic energy of a moving body is
#
# $$
# E_k=\frac{1}{2}mv^2.
# $$
#
# This energy may be transferred or partitioned among different physical processes:
#
# $$
# E=E_1+E_2+\cdots+E_n.
# $$
#
# ### Corollary 1
#
# Energy may be transferred as work:
#
# $$
# W=\int \mathbf{F}\cdot d\mathbf{x}.
# $$
#
# When applied to another body, this work may change its kinetic energy, momentum, or trajectory:
#
# $$
# \Delta E_k=W.
# $$
#
# Thus, the same total energy may produce different physical effects.
#
#
#
# ---
#
# ## Proposition 3: Probability Dilation
#
# Probability dilation was derived from the DA-prefix anomaly analysed in `experiment.ipynb`.
#
# It describes how a computational field modifies the expected probability of a state, it is to be defined as a computational field (\gamma) which is unified with a probabilistic system (p_exp) which changes the probabilistic dynamic of that system.
#
# $$
# p_{\mathrm{obs}}
# =
# \gamma p_{\mathrm{exp}}.
# $$
#
# Therefore,
#
# $$
# \gamma
# =
# \frac{p_{\mathrm{obs}}}{p_{\mathrm{exp}}}.
# $$
#
#
# ### Corollary 1: Deriving $\frac{mv^2}{2ke}$
#
# **Please note:** This was the initial attempt to derive the temperature-dilation formulas. The resulting expressions were later independently supported through the \(K\)-\(e\) bridge and the equipartition theorem, which produced identical terms and thereby demonstrated that the original conjecture was accurate.
#
# In experiment.ipynb, we postulated the relation $ p_{\mathrm{obs}} =\gamma p_{\mathrm{exp}}$. The phenomenon observed in that experiment was traced directly to the Boltzmann distribution, where the occurrence of low-probability (unlikely) states was responsible for producing the effect. Substituting this into the Boltzmann form allowed us to construct a strong estimate of the dilation factor, expressed in terms of both time and temperature. We then translated this into the corresponding relativistic terms, arriving at two distinct dilation factors by the end of the derivation.
#
# Assume the observed probability is dilated by a factor $\gamma$:
#
# $$
# p_{\text{obs}} = \gamma\, p_{\text{exp}}.
# $$
#
# Substitute the Boltzmann form into the dilation:
#
# $$
# p_{\text{obs}} \propto \gamma\, e^{-E_{\text{exp}}/(k_B T)}.
# $$
#
#
# This derives to the following formula, and using the method of postulation, guided by the energy relation
#
# $$
# \Delta E=-k_B T\ln\gamma,
# $$
#
# the corresponding temperature-dilation factor is estimated as, using the derivative
#
# $$
# \boxed{
# \gamma_d
# \approx
# \frac{1}
# {1-\frac{k_B T}{k_e\gamma}}
# }.
# $$
#
# to transfer the terms above to relativistic terms we have the total:
#
#
# $$\boxed{\frac{k_B T}{k_e\gamma} \approx \frac{mv^2}{2k_e}}$$
#
# This is to be understood as the contribution to dilation arising from multiplicity (an enumeration of particles) — that is, a source of dilation distinct from $v^2/c^2$. We therefore sought a term capable of capturing this separately, which we derived later in the analysis.
#
#
#
# ### Scholium 1: The effect of the statistical model on the interpretation of the dilation term associated with multiplicity (particle enumeration).
#
# The statistical model helped us derive three main things:
#
# 1. The field’s role is defined by what parts of the system it acts on and how it changes the energy landscape. In this framework, kinetic energy can only be allocated and reallocated via Newtonian dynamics: motion changes only when forces act, and forces enter as external interactions. The field therefore influences the system by introducing effective external forces that modify particle trajectories, after which energy is redistributed—potentially through highly targeted, “collision-at-a-distance” interactions that replicate the same redistribution you would normally attribute to direct collisions.
#
#     (a) The mechanism by which the field transforms and redistributes energy by altering the effective forces which causes a change in the probability of an event.
#
#     (b) The channel through which energy is expended for computational purposes (i.e., a portion of the system’s kinetic energy is consumed to perform these computational duties).
#
# 2. The processing factor $\frac{m v^2}{2k_e}$ that is used to derive the dilation formula.
#
# ### Scholium 2:  Understanding Thermodynamic Multiplicity: Its Relation to Particle Enumeration and the Subsequent Incorporation of the Term into the Relativistic Formulation
#
# A mathematical structure exists connecting statistical mechanics and thermodynamics with relativity. Where this mathematical correspondence is not exact, the connection should be understood as conceptual rather than strictly equivalent. Consequently, when a thermodynamic formulation produces a term that is incompatible with relativity or the broader physical framework, that contribution may be incorporated into the corresponding physical constant, provided that doing so preserves the consistency of the resulting formulation.
#
#
# **IMPORTANT:** The term $k_e\gamma$ contains an associated multiplicity term that accounts for the enumeration of particles. This multiplicity is specific to the thermodynamic formulation and therefore requires a corresponding relativistic analogue.
#
# During the first transfer into relativistic terms,
#
# $$
# \frac{k_B T}{k_e\gamma} \rightarrow \frac{mv^2}{2k_e},
# $$
#
# The multiplicity contribution was effectively absorbed into the constant \(k_e\), based on the premise that the mathematical representation of multiplicity is structurally different between statistical mechanics and the relativistic framework. At this stage, the multiplicity term was therefore not represented explicitly; instead, its contribution was incorporated into the physical constant on the relativistic side of the correspondence. The term was subsequently derived explicitly from an independent system, providing a relativistic analogue for the multiplicity contribution and establishing the mathematical structure that had previously been represented only implicitly.
#
#
# ### Corollary 2: $\frac{k_B T}{k_e\gamma}$ to describe $v^2/c^2$ more explicity
#
# The term
#
# $$
# \frac{k_B T}{k_e \gamma}
# $$
#
# derived from Corollary 1, specifies that the true definition of $v^2/c^2$ is in fact an energy ratio, $\tfrac{1}{2}mv^2 \big/ \tfrac{1}{2}mc^2$, which is how we will define it going forward. The issue is that within Galilean relativity, any term produced relativistically omits the underlying causes of motion — and so this term could never be correctly defined within a Galilean framework. The Boltzmann distribution, by contrast, provides a better description of it, since it captures the causal, statistical origin of the motion that Galilean relativity leaves out.
#
# The relativistic terms will now be defined as either:
#
# $$
# \boxed{
# \frac{mv^2}{mc^2}
# }
# $$
#
# which we will define equivalently as
#
# $$
# \boxed{
# \frac{\frac{1}{2}mv^2}{\frac{1}{2}mc^2}
# }
# $$
#
# noting that the factor of $\frac12$ cancels in both numerator and denominator, so the two forms are interchangeable — we may state the term either with or without the halves included.
#
# ### Scholium: Thermodynamic Bridge
#
#
# With appropriate guidance from the explicit terminology developed within Computational Relativity, we were able to interpret the term \(v^2/c^2\) energetically as the ratio
#
# $$
# \frac{\frac{1}{2}mv^2}{\frac{1}{2}mc^2}.
# $$
#
# This provided a direct energetic interpretation of the relativistic quantity and, through the terminology and conceptual framework of Computational Relativity, allowed us to make an accurate conjecture about the required mathematical relationship, leading to the development of the \(K\)-\(e\) relation.
#
#
# $$ K-e$$
#
# The K-e equates to the following formula (remember this was done via intuition and computational terminology in computational relativity, this actual term was derived using a thought experiment in Lorrentz Transformations months later):
#
# $$
# \frac{1}{2}mv^2
# =
# \frac{1}{2}mv'^2
# -
# \frac{1}{2}\left(\frac{\frac{1}{2}mv^2}{\frac{1}{2}mc^2}\right)mv'^2
# $$
#
#
# The significance of this relation became clearer when it provided a bridge to thermodynamics. Because thermodynamic terminology is often expressed in comparatively coarse quantities, terms such as \(k_B T\) can be interpreted directly as energy scales. This makes it possible to transfer the explicit energetic terminology established in Computational Relativity into thermodynamic expressions.
#
# K-e relates to the equipartition theorem in thermodynamics
#
# $$
# \frac{3}{2}N k_B T
# =
# \frac{3}{2}N k_B T'
# -
# \left(
# \frac{k_B T}{k_e}
# \right)
# \frac{3}{2}N k_B T',
# $$
#
# Remarkably, the initial conjecture that the relevant thermodynamic correction would involve the quantity
#
# $$
# \frac{k_B T}{k_e\gamma} \rightarrow \frac{k_B T}{k_e}
# $$
#
# was subsequently supported through this bridge. The reason the $\gamma$ term effectively becomes unity in the equipartition formulation is that the number of particles $N$ appears outside the energy term. When the same relationship is derived using the multiplicity $\Omega$ within the Boltzmann entropy definition, $N$ initially appears within the multiplicity term. However, after carrying out the derivation, the dependence on $N$ is brought outside the resulting expression. Consequently, the final form appears without the $k_e\gamma$ factor. By applying the equipartition theorem, we obtained the same terms independently, providing a confirmation of the original relationship that had initially been inferred from the terminology and energetic interpretation alone.
#
#
#
# ### Corollary 3: Combination with relativistic motion
#
# In Computational Relativity, probability dilation occurs when a configurational computational process requires additional processing time, producing a dilation in the resulting configurational state.
#
# The combined effect of probability dilation and relativistic motion is represented by
#
#
# $$
# \frac{mv_t^2}{mc^2}
# $$
#
# In Corollary 1, we state that this $\frac{mv^2}{2k_e}$ term belongs to the field of multiplicity (i.e., multiple particles). By definition, the field of motion is "unified" with the field of multiplicity via the unification operator $\times$, representing multiplication, giving the following field contribution:
#
#
#
# $$
# \boxed{
# D_{\mathrm{field}}
# =
# \frac{mv^2}{mc^2}\times
# \frac{mv^2}{2k_e}
# }
# $$
#
# The remaining non-field motion contribution is
#
# $$
# \boxed{
# D_{\mathrm{motion}}
# =
# \frac{mv^2}{mc^2}
# \left(
# 1-\frac{mv^2}{2k_e}
# \right)
# }
# $$
#
#
# The total demand is therefore
#
# $$
# D_{\mathrm{total}}
# =
# D_{\mathrm{motion}}
# +
# D_{\mathrm{field}}
# $$
#
# To keep the speed of light constant, the field's contribution must be drawn from within the total computational power of the motion, not added on top of it. The remaining terms make up the rest of that total, and together they recover the original quantity in full. This shows the field's share was always implicit within the total — so the earlier derivation isn't invalidated, only shown to have a hidden contribution embedded in it.
#
# $$
# D_{\mathrm{total}}
# =
# \frac{mv^2}{mc^2}
# \left[
# 1-\frac{mv^2}{2k_e}
# +
# \frac{mv^2}{2k_e}
# \right] = \frac{mv_t^2}{mc^2}
# $$
#
#
# The derivation here comes from the method of postulation which was guided by the philosophy of the system which interprets relativity as a symptom of a computational process. The definition is produced by the idea that a proportion of the energy is expended for computational purposes. We first introduced the formulation using our intuition-driven method rather than a step-by-step derivation. Independently, the same formula can also be derived through a separate first-principles calculation. Because these two different routes produce the exact same result, the original intuition is validated and the formula is confirmed to be consistent with the underlying energy-allocation pattern. The following marks the starting point of the intuition-driven pattern that led to the same conclusions:
#
# $$
# K' = K - e,
# $$
#
#
# By taking the current kinetic energy and dividing it by the constant that represents the energetic limit the field can handle, we obtain:
#
#
# $$
# \frac{1}{2}mv^2
# =
# \frac{1}{2}mv'^2
# -
# \frac{1}{2}\left(\frac{mv_t^2}{mc^2}\right)mv'^2
# $$
#
# Factoring the right-hand side gives
#
# $$
# \frac{1}{2}mv^2
# =
# \frac{1}{2}mv'^2
# \left(
# 1-\frac{mv_t^2}{mc^2}
# \right).
# $$
#
# Therefore,
#
# $$
# \boxed{
# \gamma
# =
#
# \frac{1}
# {\sqrt{1-\frac{mv_t^2}{mc^2}}}
# }.
# $$
#
# ### Corollary 4: Derivation of $k_e$ from $\frac{mv^2}{ke}$
#
# The term $k_e \gamma$ which was shown Corollary 2, collapses into $k_e$ in the physical relativistic limit (where the multiplicity term is now contained in), so we needed to identify a location where $\gamma$ could instead be expressed as a multiple-particle system. The combinatorial term arising from the Taylor series fits this criterion exactly. Note that we had also almost derived this independently in `derivation-biology.ipynb`.
#
# From
#
# $$
# \boxed{
# \gamma
# =
# 1
# +\frac12\frac{mv^2}{mc^2}
# +\frac38\left(\frac{mv^2}{mc^2}\right)^2
# +\frac5{16}\left(\frac{mv^2}{mc^2}\right)^3
# +\frac{35}{128}\left(\frac{mv^2}{mc^2}\right)^4
# +\frac{63}{256}\left(\frac{mv^2}{mc^2}\right)^5
# +\cdots
# }
# $$
#
# with general term
#
# $$
# \boxed{
# \gamma
# =
# \sum_{n=0}^{\infty}
# \frac{\binom{2n}{n}}{4^n}
# \left(\frac{mv^2}{mc^2}\right)^{n}
# }
# $$
#
# so the multiplicity term is
#
# $$
# a_n
# =
# \frac{\binom{2n}{n}}{4^n}.
# $$
#
# We then produced the term equivalent in general physics to state that, the $\gamma$ term collapsed into the k_e term, which was later defined properly:
#
# $$
# \frac{k_{b}T}{k_{e}\gamma} = \frac{mv^2}{2k_e}
# $$
#
# and then got the clearer definition of the k_e term, to rechieve the maximum equivalent
#
# $$
# \frac{mc^2}{2k_e}
# =
# \frac{\binom{2n}{n}}{4^n}.
# $$
#
# Which derived to
#
# $$
# \boxed{
# k_{e,\max}
# =
# \frac{1}{2a_n}mc^2
# }
# $$
#
# For all values of $v$, we obtain the complete definition, where at the maximum limit $v^2/c^2=1$, the expression reduces to the corresponding term above.
#
# $$
# \boxed{
# k_e(v,n)
# =
# \frac{mv^2}
# {2a_n\left(\frac{v^2}{c^2}\right)^n}
# }
# \qquad\longrightarrow\qquad
# \boxed{
# k_{e,\max}^{(n)}
# =
# \frac{mc^2}{2a_n}
# }
# $$
#
# ### Corollary 5: Entropy and biological organisms caused by a computational field dealing with multiplicities
#
# Within Computational Relativity, we state that the index $n$ in this expansion represents a multi-particle system — each term in the sum corresponds to the contribution of an $n$-particle interaction. It is through these relations and interactions between particles that phenomena such as entropy are generated.
#
# $$
# \boxed{
# \gamma
# =
# \sum_{n=0}^{\infty}
# \frac{\binom{2n}{n}}{4^n}
# \left(\frac{mv^2}{mc^2}\right)^{n}
# }
# $$
#
# Within computational relativity, the terminology and framework established in thermodynamics—particularly the concept that multi-particle dilation is possible—provided a conceptual meaning for the individual terms of the Taylor series. Using classical relativity alone, which describes relativistic effects primarily through the principle that the speed of light is constant, would be insufficient to adequately account for these terms. Computational relativity provides a more consistent framework for describing them, incorporating phenomena that would otherwise remain unrepresented due to the absence of the corresponding terms within the classical formulation.
#
# ### Corollary 6: Distinguishing Computational Systems by the Form given in $\left(\frac{mv^2}{mc^2}\right)^n$
#
# Computational relativity alters the interpretation of the relativistic quantity
#
# $$
# \frac{v^2}{c^2}
# $$
#
# by treating it as an energy-cap relation rather than solely as a kinematic ratio. This reinterpretation changes the meaning of the quantity by incorporating not only the magnitude of the relativistic state, but also the **form** through which the computational system is organized.
#
# Consequently, two computational systems can possess the same underlying relativistic structure while remaining distinguishable by virtue of their form. The expression
#
# $$
# \left(\frac{mv^2}{mc^2}\right)^n
# $$
#
# can therefore be used to represent different classes of computational systems according to the organization and interpretation of their states. For example, one may define
#
# $$
# \boxed{
# \left(\frac{mv^2}{mc^2}\right)^n
# \text{ as a system of entropy}
# }
# $$
#
# while another may be defined as
#
# $$
# \boxed{
# \left(\frac{mv^2}{mc^2}\right)^n
# \text{ as a system of biology}.
# }
# $$
#
# The distinction therefore arises from the **computational form** imposed upon the same underlying relativistic quantity. In this sense, computational relativity provides a framework in which \(v^2/c^2\) can describe not merely a limit on energy, but the computational structure through which different physical systems are organized.
#
#
# ### Corollary 7: State Space Deformation
#
# State-space deformation occurs when probability dilation alters how energy is partitioned, giving rise to highly organised probabilistic systems. It is analogous to gravitational curvature, except that the curvature is expressed through molecular configuration.
#
#
# ### Corollary 8: Velocity Dilation Derivation and Thought Experiment
#
# In this section, we formally derive velocity dilation using a direct mathematical methodology, distinct from the method of postulation used to establish the terms introduced in Proposition 3, Corollary 1. As we can see the skeleton below:
#
# $$
# \frac{1}{2}mv^2
# =
# \frac{1}{2}mv'^2
# -
# \frac{1}{2}\left(\frac{\frac{1}{2}mv^2}{\frac{1}{2}mc^2}\right)mv'^2
# $$
#
# can be used to derive the following terms:
#
# $$v'=\frac{v}{\sqrt{1-\frac{v^2}{c^2}}}$$
#
# However, a distinct methodology is required to independently arrive at the same conclusion. Below is the methodology described through a thought experiment:
#
#
# Consider a train moving horizontally at velocity
#
# $$
# V=0.9c.
# $$
#
# Inside the train, an object moves vertically upward with velocity
#
# $$
# v.
# $$
#
# The velocity (v) is measured in the train’s own reference frame. We want to determine the effective vertical velocity measured by an observer standing on the ground.
#
# We compare two cases:
#
# 1. The train is at rest relative to the ground observer.
# 2. The train moves horizontally at (0.9c).
#
# A particle moving perpendicular to the horizontal motion will have its observed perpendicular velocity contracted according to the following relation:
#
# $$
# v=\frac{s}{t},
# \qquad
# t'=\frac{t}{\sqrt{1-\frac{v^2}{c^2}}}
# $$
#
# $$
# v=\frac{s}{t'}
# =\frac{s}{t}\sqrt{1-\frac{v^2}{c^2}}
# $$
#
# $$
# v
# =v'\sqrt{1-\frac{v^2}{c^2}}
# $$
#
#
# If the **observed perpendicular velocity** is set equal to the train velocity (V), then
#
# $$
# v=v'\sqrt{1-\frac{v^2}{c^2}}=V
# $$
#
# Therefore,
#
# $$
# \boxed{
# v'=\frac{v}{\sqrt{1-\frac{v^2}{c^2}}}
# }
# $$
#
# ### Scholium 1: Motion and Relative Probability
#
# In computational relativity, we introduce an additional dilation factor for **probability dilation**, while retaining the existing dilation structure associated with **motion**. The framework therefore distinguishes between two related sources of dilation, each expressed from both a physics perspective and a thermodynamic perspective.
#
# | Perspective | Computational Requirement for Motion | Computational Requirement for Probability Dilation |
# |---|---|---|
# | **Physics perspective** | Processing factor as the proportion of kinetic energy relative to the motion energy cap:<br><br>$\frac{\frac{1}{2}mv^2}{\frac{1}{2}mc^2} = \frac{v^2}{c^2}$ | Processing factor as the proportion of kinetic energy relative to the probability-energy scale:<br><br>$\frac{mv^2}{2k_e}$ |
# | **Thermodynamic perspective** | Processing factor as the proportion of thermal energy relative to the motion-energy scale:<br><br>$ \frac{\frac{3}{2}Nk_BT}{\frac{3}{2}Nk_m} = \frac{k_B T}{k_m}$ | Processing factor as the proportion of thermal energy relative to the probability-energy scale modified by dilation:<br><br>$ \frac{\frac{3}{2}Nk_BT}{\frac{3}{2}Nk_e} = \frac{k_B T}{k_e}$ |
#
#
# ---
#
# ## Proposition 4: The Boltzmann distribution describes equilibrium probabilities
#
# For a microscopic system in thermal equilibrium with a heat bath,
#
# $$
# p_i=\frac{e^{-E_i/(k_B T)}}{Z},
# $$
#
# where
#
# $$
# Z=\sum_j e^{-E_j/(k_B T)}.
# $$
#
# The distribution gives the probability that the system occupies the energy state (E_i).
#
# The interaction with the heat bath is represented implicitly through the equilibrium temperature (T). The distribution does not specify how energy is exchanged or how (E_i) is physically composed.
#
# Without an additional multiplicity factor,
#
# $$
# p_i\propto e^{-E_i/(k_B T)},
# $$
#
#
#
# ### Corollary 1
#
# The Boltzmann distribution describes the relative likelihood of equilibrium energy states, not the origin, structure, or partitioning of the energy within them.
#
# ### Corollary 2
#
# The relationship between the Boltzmann distribution and relativity in a multiparticle system can be expressed through probability dilation. When probability dilation is represented as a computational field, the multiplicity provides the corresponding representation of that field within the system. The presence of this multiplicity changes the rate at which the system generates its energetic configuration as it approaches equilibrium. Consequently, the equilibrium state can be reached over a reduced elapsed time relative to the corresponding system in the absence of the multiplicity field.
#
# ### Corollary 3 Boltzmann distribution past and future relation to time
#
# Computational relativity describes thermodynamics in a computational manner, with its terminology identifying conceptual relationships between structures in thermodynamics and corresponding structures in computational relativity. Terms that are mathematically incompatible but conceptually related can be transferred through constants, as previously demonstrated with (where the multiplicity defined in classical relativity is defined through another mechanism)
#
# $$
# \frac{k_B T}{k_e\gamma}
# $$
#
# and
#
# $$
# \frac{mv^2}{2k_e}.
# $$
#
# Concepts within thermodynamics can therefore help describe computational relationships between different states. For example, the partition function is related to free energy in the following way:
#
# $$
# \boxed{
# Z
# =
# \sum_i e^{-E_i/(k_B T)}
# }
# $$
#
# The **Helmholtz free energy** is then defined as
#
# $$
# \boxed{
# F
# =
# -k_B T\ln Z
# }
# $$
#
# Within the interpretation of computational relativity, free energy is defined in relation to a range of possible states. Some of these states may never come into existence, which implies that free energy is logically tied to states that are almost imaginary. States that are not presently realized can still contribute to the description of the current state.
#
# This can only be understood through a computational framework: an unrealized state could contribute to the current state if it were used as a computational input. The partition function (Z) and its relation to free energy should therefore have suggested to those who derived it that we are in a computer or this could only possibly happen within a computational system. This matters because it has further implications within computational relativity itself. Not every structure in thermodynamics can be translated mathematically into the corresponding terms of computational relativity, but conceptual bridges can still be built between the two frameworks, and these can help guide the theory's continued development.
#
# For example, the relation between the partition function and free energy can be read as showing that states which have not come into existence, including states of the past and future, can still contribute to the description of the current state of a particle.
#
# ---
#
# ## Proposition 5: Multiplicity Definition
#
# **Multiplicity** is the number of possible configurations or states that a system can have under a given set of rules.
#
# It can be separated into two parts:
#
# * **Form:** the mathematical structure or rule used to determine the multiplicity, such as
#
# $$
# \Omega(r)=\binom{N}{r}.
# $$
#
# * **Actual multiplicity:** the numerical value produced by that form. For example,
#
# $$
# \Omega(2)=\binom{5}{2}=10.
# $$
#
#
#
# ![image.png](attachment:image.png)
#
#
# *** IMPORTANT *** Evidence for the existence of a multiplicity in physical reality that is distinct from $\Omega$, where $\Omega$ primarily represents the combinatorial character of randomness and entropy, is developed from the experiment presented in `experiment.ipynb`. This second form of multiplicity is represented through the $\gamma$-multiplicity.
#
#
# ### Corollary 1: Multiplicity Form Determines Energy Partitioning
#
# Two multiplicities can have the same **actual value** while differing in their **form**.
#
# $$
# \Omega_A=\Omega_B,
# \qquad
# F_A\neq F_B.
# $$
#
# The form describes the structure of the multiplicity. Therefore, when multiplicity is used to describe the distribution of energy within a system, different multiplicity forms can represent different structures of energy partitioning.
#
# For example,
#
# $$
# k_B T\ln\Omega
# $$
#
# can represent the energy associated with the entropy of the system, while
#
# $$
# k_B T\ln\gamma
# $$
#
# can represent the biological-energy contribution associated with the $\gamma$-multiplicity in the proposed framework.
#
# ### Corollary 2:
#
# The multiplicity terms
#
# $$
# k_B T \ln\gamma
# $$
#
# and
#
# $$
# k_B T \ln\Omega
# $$
#
# imply that, without multiplicity, the system could not favor the states determined by its form. The existence of the $\gamma$ multiplicity is demonstrated by the experiment in `experiment.ipynb`. This implies two things: that the system is computational, and that a multiplicity is replaceable. By replaceable, I mean that the computational system shaping the dynamics of a given thermodynamic system can be swapped for a different form over time. This is also shown in Corollary 6 of Proposition 4, which covers the description in standard relativity.
#
# For example:
#
# - **Time 1, location 1:** Form 1 (entropic) is instantiated.
# - **Time 2, location 1:** Form 2 (biological) is instantiated.
#
# ### Corollary 3: Understanding the Terms as Descriptions of Thermodynamic Equilibrium
#
# Thermodynamic expressions involving
#
# $$
# k_B T\ln\Omega
# $$
#
# The model can describe the energy associated with the structure of a system at equilibrium. However, reaching equilibrium requires a sequence of transitions that occur before the equilibrium state is established, and the model does not explicitly describe these transitions themselves.
#
# Instead, the transitions are determined by the internal structure of the multiplicity term, represented by its **form** (as described in the proposition related to this corollary). We interpret this underlying structure as the **computational component** of the system.
#
# Within this framework, without the multiplicity corresponding to a particular form, the transitions required to realize that state could not occur. The time required to produce the equilibrium state would therefore approach infinity. That is, multiplicity reduces the time required to produce a biological state. In Computational Relativity, this effect is represented as a corresponding reduction in the dilation term. That is, $\sqrt{1-\frac{v^2}{c^2}} = 1$
#
#
# $$
# \boxed{
# \text{Multiplicity}\rightarrow
# \text{finite partitioning time}
# }
# $$
#
# $$
# \boxed{
# \text{No multiplicity}\rightarrow
# t_{\mathrm{eq}}\rightarrow\infty
# }
# $$
#
#
# ### Demonstration 1: Multiplicity as a representation of reducing dilation factor
#
# Consider the Boltzmann factor
#
# $$
# p=e^{-E/(k_BT)}.
# $$
#
# For a system with
#
# $$
# \frac{E}{k_BT}=10,
# $$
#
# we obtain
#
# | $E/(k_BT)$ | $p(E)=e^{-E/k_BT}$ |
# |---:|---:|
# | $0$ | $1.000000$ |
# | $1$ | $0.367879$ |
# | $2$ | $0.135335$ |
# | $3$ | $0.049787$ |
# | $4$ | $0.018316$ |
# | $5$ | $0.006738$ |
# | $6$ | $0.002479$ |
# | $7$ | $0.000912$ |
# | $8$ | $0.000335$ |
# | $9$ | $0.000123$ |
# | $10$ | $0.0000454$ |
# | $E\to\infty$ | $\to 0$ |
#
# The final case follows directly from
#
# $$
# p=\Omega e^{-E/(k_BT)}.
# $$
#
# Setting
#
# $$
# \Omega=e^{10}
# $$
#
# gives
#
# $$
# p=e^{10}e^{-10}
# =e^0
# =1.
# $$
#
# Therefore, the multiplicity progressively offsets the exponential suppression until the effective term becomes zero and the statistical weight reaches
#
# $$
# \boxed{p=1}.
# $$
#
# In Computational Relativity, this is compared with the limiting form of the inverse Lorentz dilation factor,
#
# $$
# \sqrt{1-\frac{v^2}{c^2}}.
# $$
#
# When there is no dilation,
#
# $$
# \sqrt{1-\frac{v^2}{c^2}}=1.
# $$
#
# Thus, the proposed correspondence is
#
# $$
# \boxed{
# \Omega\rightarrow e^{10}
# \quad\Longrightarrow\quad
# p\rightarrow1
# \quad\Longleftrightarrow\quad
# \text{dilation factor}\rightarrow1
# }
# $$
#
# In this interpretation, increasing multiplicity reduces the effective statistical or computational dilation until the system reaches the limiting value of $1$.
#
#
#
# ## Proposition 6: Energy may be statistically partitioned by different forms of multiplicity
#
# The statistical weight of state (i) is
#
# $$
# w_i=\Omega_i e^{-E_i/(k_B T)}.
# $$
#
# Here, $\Omega_i$ represents the multiplicity associated with the entropy of state (i). The multiplicity factor is defined as a representation of the computational effects of a field on the probabilistic dynamics and effective energy structure of a system. Without the $\Omega_i$ term, the model does not include the additional configurational effects attributed to the computational field. In that case, the expression reduces to the standard Boltzmann distribution, in which state probabilities are determined by the exchange of thermal energy between a microscopic system and a heat reservoir (when reaching equilibrium) [REFER PROPOSITION 4].
#
# Its probability is
#
# $$
# p_i=\frac{\Omega_i e^{-E_i/(k_B T)}}{Z},
# $$
#
# where
#
# $$
# Z=\sum_j \Omega_j e^{-E_j/(k_B T)}.
# $$
#
# When discussing multiplicity, we are describing how the rules governing movement generate the dynamics of a system. Multiplicity therefore determines how energy is partitioned across those dynamics (REFER PROPOSITION 1). Two forms of multiplicity are proposed.
#
#
# ### Multiplicity 1: Random entropic multiplicity
#
# Ordinary thermodynamic multiplicity is denoted by
#
# $$
# \Omega_{i,\mathrm{r}},
# $$
#
# with entropy
#
# $$
# S_{i,\mathrm{r}}=k_B\ln\Omega_{i,\mathrm{r}}.
# $$
#
# The statistical weight becomes
#
# $$
# w_{i,\mathrm{r}}
# =
#
# e^{-\left(E_i-TS_{i,\mathrm{r}}\right)/(k_B T)}.
# $$
#
# The term
#
# $$
# -TS_{i,\mathrm{r}}
# $$
#
# represents the contribution of random microscopic multiplicity.
#
# ### Multiplicity 2: Biological multiplicity
#
# For a biological state, a computational field introduces a dilation factor which changes the dynamics of how the energy is partitioned within the thermodynamic system
#
# $$
# \gamma_i.
# $$
#
# The statistical weight becomes
#
# $$
# w_{i,\mathrm{b}}
# =
#
# \gamma_i e^{-E_{i,\mathrm{b}}/(k_B T)}.
# $$
#
# Equivalently,
#
# $$
# w_{i,\mathrm{b}}
# =
#
# e^{-\left(E_{i,\mathrm{b}}-k_B T\ln\gamma_i\right)/(k_B T)}.
# $$
#
# Therefore, the effective energy is
#
# $$
# E_{i,\mathrm{eff}}
# =
#
# E_{i,\mathrm{b}}-k_B T\ln\gamma_i.
# $$
#
# The term
#
# $$
# -k_B T\ln\gamma_i
# $$
#
# has the same mathematical form as (-TS), but is proposed to represent ordered biological energy partitioning rather than random microscopic multiplicity.
#
# *** IMPORTANT *** Evidence for the existence of a multiplicity in physical reality that is distinct from $\Omega$, where $\Omega$ primarily represents the combinatorial character of randomness and entropy, is developed from the experiment presented in `experiment.ipynb`. This second form of multiplicity is represented through the $gamma$-multiplicity.
#
#
# ### Corollary 2: Partitioning and Energy Terms
#
# Although the total physical energy of state (i) remains (E_i), the multiplicity of that state introduces an effective statistical energy contribution,
#
# $$
# w_i=\Omega_i e^{-(E_i)/(k_B T)}.
# $$
#
# Which derives to and includes the term $-k_B T\ln\Omega_i$
#
# $$
# w_i = e^{-(E_i-k_B T\ln\Omega_i)/(k_B T)}.
# $$
#
# The term below describes an effective “energy reduction.” This should not be interpreted as a reduction in the total physical energy of the system because the total energy of the state still remains $E_i$. Rather, it represents the effect that a computational field has on the statistical weight of a particular state, expressed through an equivalent shift in its effective energy.
#
# $$
# -k_B T\ln\Omega_i.
# $$
#
# Accordingly, the statistical behaviour of the state can be represented by the effective energy
#
# $$
# E_i-k_B T\ln\Omega_i.
# $$
#
# Thus, multiplicity does not directly remove energy from (E_i). Instead, it changes how (E_i) is represented, because the total energy is partitioned to include the configurational contribution associated with the computational field. In this description, a portion of the effective energetic contribution is represented by (that is, a portion of $E_i$ includes the energy description below)
#
# $$
# k_B T\ln\Omega_i.
# $$
#
#
# ### Corollary 3: Energy Terms
#
# The energy terms in the Boltzmann distribution are modified when the multiplicity factors $\gamma$ or $\Omega$ are introduced into the statistical weight. When these factors multiply the Boltzmann probability term, their effect can be represented as an equivalent shift in the effective energy associated with each state, as shown below:
#
#
# For random multiplicity,
#
# $$
# E_{i,\mathrm{eff}}
# =
# E_i-TS_{i,\mathrm{r}}.
# $$
#
# For biological multiplicity,
#
# $$
# E_{i,\mathrm{eff}}
# =
#
# E_{i,\mathrm{b}}-k_B T\ln\gamma_i.
# $$
#
# Thus, $E_{i,\mathrm{b}}$ remains the physical energy of the state, while the dilation term modifies its statistical weight. In both cases $E_i$ is modified to include either $TS_{i,\mathrm{r}}$ or $k_B T\ln\gamma_i$ within the contents of $E_{i,\mathrm{b}}$ depending upon the type of multiplicity.
#
# ---
#
# ## Proposition 6: Biological energy is not fully described by ordinary free energy
#
# Ordinary Helmholtz free energy is
#
# $$
# F=E-TS.
# $$
#
# This expression accounts for ordinary thermodynamic entropy and random multiplicity.
#
# A biological system may also contain organised energy contributions:
#
# $$
# E_{\mathrm{b}}
# =
#
# E_{\mathrm{thermal}}
# +
# E_{\mathrm{chemical}}
# +
# E_{\mathrm{structural}}
# +
# E_{\mathrm{functional}}
# +
# E_{\mathrm{other}}.
# $$
#
# Its effective statistical energy may therefore be written as
#
# $$
# E_{\mathrm{b,eff}}
# =
# E_{\mathrm{b}}-k_B T\ln\gamma_{\mathrm{b}}.
# $$
#
# The term
#
# $$
# -k_B T\ln\gamma_{\mathrm{b}}
# $$
#
# changes the statistical weight of the biological state. It does not necessarily imply a reduction in its total physical energy.
#
# Therefore,
#
# $$
# \boxed{
# E_{\mathrm{b}}
# =
#
# \text{physical energy of the biological state}
# }
# $$
#
# while
#
# $$
# \boxed{
# E_{\mathrm{b,eff}}
# =
#
# E_{\mathrm{b}}-k_B T\ln\gamma_{\mathrm{b}}
# }
# $$
#
# describes its effective energy within the probability distribution.
#
#
# ---
#
# ## Proposition 7: Temperature Dilation
#
# Assume the observed probability is dilated by a factor $\gamma$:
#
# $$
# p_{\text{obs}} = \gamma\, p_{\text{exp}}.
# $$
#
# Substitute the Boltzmann form into the dilation:
#
# $$
# p_{\text{obs}} \propto \gamma\, e^{-E_{\text{exp}}/(k_B T)}.
# $$
#
#
# This derives to the following formula, and using the method of postulation, guided by the energy relation
#
# $$
# \Delta E=-k_B T\ln\gamma,
# $$
#
# the corresponding temperature-dilation factor is estimated as, using the derivative
#
# $$
# \boxed{
# \gamma_d
# \approx
# \frac{1}
# {1-\frac{k_B T}{k_e\gamma}}
# }.
# $$
#
# This factor describes the proposed dilation of temperature produced by the combined influence of thermal energy and probability dilation.
#
# ---
#
# ## Proposition 8: Energy–temperature bridge
#
# The computational-relativity model begins with the energy-allocation relation
#
# $$
# K'=K-e.
# $$
#
# This expands into the following form:
#
# $$
# \frac{1}{2}mv^2
# =
# \frac{1}{2}mv'^2
# -
# \frac{1}{2}\left(\frac{mv^2}{2k_e}\right)\left(\frac{\frac{1}{2}mv^2}{\frac{1}{2}mc^2}\right)mv'^2
# $$
#
#
# For relativistic motion, the dilation term
#
# $$
# \frac{\frac{1}{2}mv^2}{\frac{1}{2}mc^2}
# $$
#
# is more physically explicit than the reduced form because Galilean relativity describes motion kinematically while omitting the underlying physical causes and energetic structure of that motion.
#
# $$
# \frac{v^2}{c^2},
# $$
#
# because it preserves the underlying energy ratio. This provides a direct bridge to thermodynamics, where relations must be expressed in compatible energy units. By contrast, the reduced velocity ratio omits the mass and momentum structure required for this mapping.
#
# Which relates to the equipartition theorem in thermodynamics
#
# $$
# \frac{3}{2}N k_B T
# =
# \frac{3}{2}N k_B T'
# -
# \left(
# \frac{k_B T}{k_e}
# \right)
# \frac{3}{2}N k_B T',
# $$
#
#
# Therefore, the temperature ratio for probability dilation is
#
# $$
# T'
# =
# \frac{T}
# {
# 1 - \frac{k_B T}{k_e}
# }.
# $$
#
# and the temperature ratio for dilation of motion is
#
# $$
# T'
# =
# \frac{T}
# {
# 1 - \frac{k_B T}{k_m}
# }.
# $$
#
# ### Scholium 1
#
#
# | Perspective | Computational Requirement for Motion | Computational Requirement for Probability Dilation |
# |---|---|---|
# | **Physics perspective** | Processing factor as the proportion of kinetic energy relative to the motion energy cap:<br><br>$\frac{\frac{1}{2}mv^2}{\frac{1}{2}mc^2} = \frac{v^2}{c^2}$ | Processing factor as the proportion of kinetic energy relative to the probability-energy scale:<br><br>$\frac{mv^2}{2k_e}$ |
# | **Thermodynamic perspective** | Processing factor as the proportion of thermal energy relative to the motion-energy scale:<br><br>$ \frac{\frac{3}{2}Nk_BT}{\frac{3}{2}Nk_m} = \frac{k_B T}{k_m}$ | Processing factor as the proportion of thermal energy relative to the probability-energy scale modified by dilation:<br><br>$ \frac{\frac{3}{2}Nk_BT}{\frac{3}{2}Nk_e} = \frac{k_B T}{k_e}$ |
#
# ### Scholium 2
#
# The table below maps the corresponding physical quantities derived using the structural bridge between kinetic energy, thermodynamics, and relativity. It displays how these terms translate into specific processing factors, such as $\frac{\frac{1}{2}mv^2}{\frac{1}{2}mc^2}$:
#
#
# | Quantity                   |                    Starting equation | Rearranged temperature definition | Meaning                                                                    |
# | -------------------------- | -----------------------------------: | --------------------------------: | -------------------------------------------------------------------------- |
# | **Actual motion energy**   | $\frac{1}{2}mv^2=\frac{3}{2}k_B T_v$ |           $T_v=\frac{mv^2}{3k_B}$ | (T_v) is the temperature scale associated with the actual motion energy.   |
# | **Motion-energy cap**      | $\frac{1}{2}mc^2=\frac{3}{2}k_B T_m$ |           $T_m=\frac{mc^2}{3k_B}$ | (T_m) is the mass-relative maximum motion-energy temperature scale.        |
# | **Probability-energy cap** |             $k_e=\frac{3}{2}k_B T_e$ |           $T_e=\frac{2k_e}{3k_B}$ | (T_e) is the temperature scale associated with the probability-energy cap. |
#
#
# The table below displays the corresponding dilation factors in thermodynamics which are reduced soley to ratios in temperature:
#
#
# | Factor                          |           Physics form | Temperature-cap form |          Cap definition |
# | ------------------------------- | ---------------------: | -------------------: | ----------------------: |
# | **Motion dilation factor**      |      $\frac{v^2}{c^2}$ |      $\frac{T_v}{T_m}$ | $T_m=\frac{mc^2}{3k_B}$ |
# | **Probability dilation factor** |    $\frac{mv^2}{2k_e}$ |      $\frac{T_v}{T_e}$ | $T_e=\frac{2k_e}{3k_B}$ |
# | **Combined factor**             | $\frac{mv^4}{2k_ec^2}$ | $\frac{T_v^2}{T_mT_e}$ |    Product of both caps |
#
#
#
# Therefore, the combined processing factor is
#
# $$
# \left(\frac{T_v}{T_m}\right)
# \left(\frac{T_v}{T_e}\right)
# =
# \frac{T_v^2}{T_mT_e}
# =
# \frac{mv^4}{2k_ec^2}.
# $$
#
#
# ### Corollary 2
#
# The methodology used in Proposition 7 produces a temperature-dilation factor through the thermodynamic relation
#
# $$
# \Delta E=-k_B T\ln\gamma,
# $$
#
# whereas this proposition derives the same general energy-allocation structure by converting motion and probability factors into temperature ratios.
#
# The two propositions therefore reach compatible dilation structures through different mechanisms: one through thermodynamic postulation and the other through an energy–temperature mapping.

# %% [markdown]
# ---
