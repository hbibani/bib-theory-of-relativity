# %% [markdown]
# ![My image](../../images/whitely.jpg)
#
#
# ## MAIN VIDEO: https://www.facebook.com/share/v/1PetYDTvh4/
#
#
# ## UNDERSTANDING THE DIFFERENCE BETWEEN THE TIME DILATION FORULAS: https://www.facebook.com/share/v/1BScDJMBUH/

# %% [markdown]
# ---
#
# # FIRST SECTION - STATISTICAL MECHANICS DERIVATION, THE STATITICAL MECHANICS DILATION FORMULA AND WORKING IN CONJUNCTION WITH BOLTZMANN
#
#
# ---
#
# ### WATCH VIDEO: https://www.facebook.com/share/v/1FWsitx9as/
#
# ### Statefulness
#
# Information can be stored, and once stored, it can be used to perform a computation. Human conventions, likewise, can serve as inputs within a computational process. For this to occur, there must exist a computational space in which information is able to undergo operations. From a purely physical standpoint, there appears to be nothing within physical space itself that fully accounts for how such computation takes place. Therefore, it is necessary to posit an absolute frame of reference containing a form of structure not present on the physical plane, and it is this structure that makes computation possible.
#
# ---
#
#
#   They reinterpret Lorentz’s results using a computational-field view in which only an **absolute reference frame** is truly inertial. Time is expressed in an absolute unit, **bibs**, so all observers must agree on how much absolute time (how many bibs) has elapsed relative to that frame (ignoring bib-dilation). By analogy with a computer’s shared clock, simultaneous processes in the absolute frame correspond to the same bib count for all observers; this universal agreement is taken as evidence for an underlying computational absolute frame and a revision of the usual inertial-frame notion, while still preserving a limited, classical-like agreement about event timing grounded in the computational framework rather than spacetime itself.
#
#   The original formula, prior to the identification of the new variable, states that all non-inertial reference frames will use the same expression to determine the amount of time that has elapsed relative to a given inertial reference frame, and will therefore agree on that elapsed time.
#
#   $$
#   \boxed{\Delta t =\frac{1}{\rho}\,\Delta\tau}
#   $$
#
# What we did was replace $\Delta t$ with a new unit, as shown in the following expression.
#
#   Let $k_B=\frac{B}{S}$ be the bibs-rate constant (units: bibs/s), representing a system-specific computational overhead that scales how proper time is counted in bibs. The bibs elapsed over a proper-time interval $\Delta\tau$ is
#
#   $$
#   \boxed{\Delta b=\frac{k_B}{\rho}\,\Delta\tau}
#   $$
#
#
#
#
#
#
#
#   and equivalently,
#
#   $$
#   \boxed{\Delta\tau=\frac{\rho}{k_B}\,\Delta b}.
#   $$
#
# ---
#
# REFER to experiment.ipynb
#
#
# We retrieved this section from the experiment, that is, this formula was created after the investigation of the DA-anomoly prefix $\gamma$:
#
# $$
# p_{\text{obs}} = \gamma\, p_{\text{exp}}.
# $$
#
# After the experimental formula above, Boltzmann related probability to energy, and it turns out that this relation works very well with the formula above. Using the following formula, we can also relate probability dilation to energy, specifically kinetic energy.
#
# Energy to Probability:
#
# $$
# p_{\text{exp}} \propto e^{-E_{\text{exp}}/(k_B T)}.
# $$
#
# Then Derive Dilation To Energy:
#
# $$
# \Delta E = -k_B T \ln\gamma
# $$
#
# ---
#
# We then got the statistical models interpretation of processing factor, which is related to the derivative of $\Delta E = -k_B T \ln\gamma$
#
# Note: The bottom is the physical dilation factor (not the probability dilation $\gamma = \frac{p_{\text{obs}}}{ p_{\text{exp}}} $  )
#
# $$\boxed{ \gamma_{d} \approx \frac{1}{1 - \frac{k_{b}T}{k_{e}\gamma}}}$$
#
# This aligns cleanly with the physical model, and the formula corresponds cleanly with the other system derived in physics - REFER - derivation-physics.ipynb file.
#
# ---

# %% [markdown]
# The statistical model helped us derive three main things:
#
# 1. The field’s role is defined by what parts of the system it acts on and how it changes the energy landscape. In this framework, kinetic energy can only be allocated and reallocated via Newtonian dynamics: motion changes only when forces act, and forces enter as external interactions. The field therefore influences the system by introducing effective external forces that modify particle trajectories, after which energy is redistributed—potentially through highly targeted, “collision-at-a-distance” interactions that replicate the same redistribution you would normally attribute to direct collisions.
#
#     (a) The mechanism by which the field transforms and redistributes energy by altering the effective forces which causes a change in the probability of an event.
#
#     (b) The channel through which energy is expended for computational purposes (i.e., a portion of the system’s kinetic energy is consumed to perform these computational duties).
#
# 2. The processing factor $\frac{m v^2}{2k_e}$ that is used to derive the dilation formula.
#
# ---

# %% [markdown]
# # SECOND SECTION - PHYSICS DERIVATION
#
# IT IS IMPORTANT TO UNDERSTAND THAT WE DERIVED THE DILATION FORMULA FOR MOTION WITHOUT INVOKING GALILEAN RELATIVITY — THAT IS, THIS SYSTEM IS FAR MORE EFFICIENT THAN THE LORENTZ DERIVATION - REFER derivation-physics.ipynb in source folder (at the bottom of document).
#
# $$ \gamma = \frac{1}{\sqrt{1-\frac{v^2}{c^2}}} $$
#
# WE COULD ALSO INFER THE DILATION OF MOMENTUM THROUGH THIS SYSTEM FAR MORE EFFICIENTLY THAN EINSTEIN: $$p = \gamma mv$$
#
# ---
#
# We first introduced the formulation using our intuition-driven method rather than a step-by-step derivation. Independently, the same formula can also be derived through a separate first-principles calculation. Because these two different routes produce the exact same result, the original intuition is validated and the formula is confirmed to be consistent with the underlying energy-allocation pattern. The following marks the starting point of the intuition-driven pattern that led to the same conclusions:
#
# $$
# K' = K - e,
# $$
#
#
# By taking the current kinetic energy and dividing it by the constant that represents the energetic limit the field can handle, we obtain:
#
# $$
# \frac{1}{2}mv^2
# =
# \frac{1}{2}mv'^2
# -
# \frac{1}{2}\left(\frac{mv^2}{2k_e}\right)mv'^2
# $$
#
#
# For the combination of both the diminished field and that of motion we must use this relation
#
# $$
# \frac{1}{2}mv^2
# =
# \frac{1}{2}mv'^2
# -
# \frac{1}{2}\left(\frac{mv^2}{2k_e}\right)\left(\frac{v^2}{c^2}\right)mv'^2
# $$
#
#
# Therefore:
#
# $$
# \gamma
# =
# \frac{1}{\sqrt{1 - \frac{m v^4}{2k_ec^2}}}
# $$

# %% [markdown]
# ---
#
# ### Transformative component of the computation
#
# One of the most important points I wanted to convey is that this occurs through the transformative aspect of relativity. That is, it is tied to the component in which the transition between two molecular states takes place. In practical terms, when the body moves, the computation associated with the next frame or state is carried out at the very moment the transition is about to occur, and it is completed at the same location, in the absolute reference frame, where the computation described in this video (for life) takes place.
