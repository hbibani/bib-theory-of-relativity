# %% [markdown]
# # PLEASE WATCH VIDEO: https://www.facebook.com/share/v/17qC4hh6H3/

# %% [markdown]
# # A low energy field has already proven to exist, REFER experiment.ipynb

# %% [markdown]
# ---
#
# ### Note: I have seen a UFO before, separate from the case presented by the Americans. It was a genuine UFO, and it was far less ambiguous than the image released by the Pentagon.
#
#
# An organism capable of producing a UFO would, by virtue of its evolutionary development, have to be angelic. But if such an organism does not intervene to protect the earth, then its behavior stands in contradiction to its supposed angelic character.
#
#
#
# There are two kinds of fields:
#
# 1. low-energy fields
# 2. high-energy fields
#
# There are also two kinds of organisms:
#
# 1. those in the absolute reference frame
# 2. those below, or within the boundary of, that frame
#
#
# There was a hidden variable in relativity that Einstein and Lorentz overlooked, namely the concept of absolute time. From this follows the idea of an absolute reference frame, which in turn allows for the existence of non-generic fields capable of producing biological organisms.
#
#
# So the creation of the UFO must come from one of two sources:
#
# 1. a high-energy field, or
# 2. an organism that exists below the boundary of the absolute reference frame
#
# But if the producer’s behavior is inconsistent with what would be expected of an angelic organism, then it is more reasonable to conclude that the UFO is the product of a high-energy field.
#
#
#
# ---
#
# # REFER EXPERIMENT, REFER SIMPLIFIED.ipynb document
#
# They may try to explain the DA-prefix number-plate anomaly by attributing it to a field produced by UFOs or aliens. But that immediately raises the same question about biological organisms, since they too fall within the field-based framework of Computational Relativity. The better conclusion is no: both are to be understood as effects of fields operating within the absolute reference frame, that is, as part of nature.
